# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("Churn_Modelling.csv")
df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender   Age  \
# 0             1    15634602   Hargrave          619    France  Female   NaN
# 1             2    15647311       Hill          608     Spain  Female  41.0
# 2             3    15619304       Onio          502    France  Female  42.0
# 3             4    15701354       Boni          699    France  Female  39.0
# 4             5    15737888   Mitchell          850     Spain  Female  43.0
# ...         ...         ...        ...          ...       ...     ...   ...
# 9995       9996    15606229   Obijiaku          771    France    Male  39.0
# 9996       9997    15569892  Johnstone          516    France    Male  35.0
# 9997       9998    15584532        Liu          709    France  Female  36.0
# 9998       9999    15682355  Sabbatini          772   Germany    Male  42.0
# 9999      10000    15628319     Walker          792    France  Female  28.0
#
# ...

# %%
# view the data 
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender   Age  \
# 0          1    15634602  Hargrave          619    France  Female   NaN
# 1          2    15647311      Hill          608     Spain  Female  41.0
# 2          3    15619304      Onio          502    France  Female  42.0
# 3          4    15701354      Boni          699    France  Female  39.0
# 4          5    15737888  Mitchell          850     Spain  Female  43.0
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
df.tail()
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender   Age  \
# 9995       9996    15606229   Obijiaku          771    France    Male  39.0
# 9996       9997    15569892  Johnstone          516    France    Male  35.0
# 9997       9998    15584532        Liu          709    France  Female  36.0
# 9998       9999    15682355  Sabbatini          772   Germany    Male  42.0
# 9999      10000    15628319     Walker          792    France  Female  28.0
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited
# 9995         96270.64       0
# 9996        101699.77       0
# ...

# %%
df.describe()
# Out:
#          RowNumber    CustomerId   CreditScore          Age        Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  9999.000000  10000.000000
# mean    5000.50000  1.569094e+07    650.528800    38.921492      5.012800
# std     2886.89568  7.193619e+04     96.653299    10.488286      2.892174
# min        1.00000  1.556570e+07    350.000000    18.000000      0.000000
# 25%     2500.75000  1.562853e+07    584.000000    32.000000      3.000000
# 50%     5000.50000  1.569074e+07    652.000000    37.000000      5.000000
# 75%     7500.25000  1.575323e+07    718.000000    44.000000      7.000000
# max    10000.00000  1.581569e+07    850.000000    92.000000     10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# std     62397.405202       0.581654      0.45584        0.499797
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              9999 non-null   float64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(3), int64(8), object(3)
# memory usage: 1.1+ MB

# %%
#accessing columns
df.columns
# Out:
# Index(['RowNumber', 'CustomerId', 'Surname', 'CreditScore', 'Geography',
#        'Gender', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard',
#        'IsActiveMember', 'EstimatedSalary', 'Exited'],
#       dtype='object')

# %%
df["Age"] # single column
# Out:
# 0        NaN
# 1       41.0
# 2       42.0
# 3       39.0
# 4       43.0
#         ...
# 9995    39.0
# 9996    35.0
# 9997    36.0
# 9998    42.0
# 9999    28.0
# Name: Age, Length: 10000, dtype: float64

# %%
df[["Gender","Age"]] # multiple columns
# Out:
#       Gender   Age
# 0     Female   NaN
# 1     Female  41.0
# 2     Female  42.0
# 3     Female  39.0
# 4     Female  43.0
# ...      ...   ...
# 9995    Male  39.0
# 9996    Male  35.0
# 9997  Female  36.0
# 9998    Male  42.0
# 9999  Female  28.0
#
# [10000 rows x 2 columns]

# %%
# accessing rows
df.iloc[0] # single row by index
# Out:
# RowNumber                  1
# CustomerId          15634602
# Surname             Hargrave
# CreditScore              619
# Geography             France
# Gender                Female
# Age                      NaN
# Tenure                     2
# Balance                  0.0
# NumOfProducts              1
# HasCrCard                  1
# IsActiveMember             1
# EstimatedSalary    101348.88
# Exited                     1
# Name: 0, dtype: object

# %%
df.iloc[0:5] # first 5 rows
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender   Age  \
# 0          1    15634602  Hargrave          619    France  Female   NaN
# 1          2    15647311      Hill          608     Spain  Female  41.0
# 2          3    15619304      Onio          502    France  Female  42.0
# 3          4    15701354      Boni          699    France  Female  39.0
# 4          5    15737888  Mitchell          850     Spain  Female  43.0
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
df.iloc[0, 2] # first rows and 3rd column
# Out:
# 'Hargrave'

# %%
df.iloc[0:2, 0:2]   # First 2 rows and first 2 columns
# Out:
#    RowNumber  CustomerId
# 0          1    15634602
# 1          2    15647311

# %%
# accessing rows by label
df.loc[0] # single row by label
# Out:
# RowNumber                  1
# CustomerId          15634602
# Surname             Hargrave
# CreditScore              619
# Geography             France
# Gender                Female
# Age                      NaN
# Tenure                     2
# Balance                  0.0
# NumOfProducts              1
# HasCrCard                  1
# IsActiveMember             1
# EstimatedSalary    101348.88
# Exited                     1
# Name: 0, dtype: object

# %%
df.loc[0, "Surname"] # first row and surname column as label
# Out:
# 'Hargrave'

# %%
df.loc[1]  # Returns the row with index label 1:
# Out:
# RowNumber                  2
# CustomerId          15647311
# Surname                 Hill
# CreditScore              608
# Geography              Spain
# Gender                Female
# Age                     41.0
# Tenure                     1
# Balance             83807.86
# NumOfProducts              1
# HasCrCard                  0
# IsActiveMember             1
# EstimatedSalary    112542.58
# Exited                     0
# Name: 1, dtype: object

# %%
# filtering data
df[df['Age'] > 30]  # filter rows where age is greater than 30
# Out:
#       RowNumber  CustomerId      Surname  CreditScore Geography  Gender   Age  \
# 1             2    15647311         Hill          608     Spain  Female  41.0
# 2             3    15619304         Onio          502    France  Female  42.0
# 3             4    15701354         Boni          699    France  Female  39.0
# 4             5    15737888     Mitchell          850     Spain  Female  43.0
# 5             6    15574012          Chu          645     Spain    Male  44.0
# ...         ...         ...          ...          ...       ...     ...   ...
# 9992       9993    15657105  Chukwualuka          726     Spain    Male  36.0
# 9995       9996    15606229     Obijiaku          771    France    Male  39.0
# 9996       9997    15569892    Johnstone          516    France    Male  35.0
# 9997       9998    15584532          Liu          709    France  Female  36.0
# 9998       9999    15682355    Sabbatini          772   Germany    Male  42.0
#
# ...

# %%
# Alternative way
df.query("Age > 30")
# Out:
#       RowNumber  CustomerId      Surname  CreditScore Geography  Gender   Age  \
# 1             2    15647311         Hill          608     Spain  Female  41.0
# 2             3    15619304         Onio          502    France  Female  42.0
# 3             4    15701354         Boni          699    France  Female  39.0
# 4             5    15737888     Mitchell          850     Spain  Female  43.0
# 5             6    15574012          Chu          645     Spain    Male  44.0
# ...         ...         ...          ...          ...       ...     ...   ...
# 9992       9993    15657105  Chukwualuka          726     Spain    Male  36.0
# 9995       9996    15606229     Obijiaku          771    France    Male  39.0
# 9996       9997    15569892    Johnstone          516    France    Male  35.0
# 9997       9998    15584532          Liu          709    France  Female  36.0
# 9998       9999    15682355    Sabbatini          772   Germany    Male  42.0
#
# ...

# %%
# Using loc for more clarity
df.loc[df['Age'] > 30]
# Out:
#       RowNumber  CustomerId      Surname  CreditScore Geography  Gender   Age  \
# 1             2    15647311         Hill          608     Spain  Female  41.0
# 2             3    15619304         Onio          502    France  Female  42.0
# 3             4    15701354         Boni          699    France  Female  39.0
# 4             5    15737888     Mitchell          850     Spain  Female  43.0
# 5             6    15574012          Chu          645     Spain    Male  44.0
# ...         ...         ...          ...          ...       ...     ...   ...
# 9992       9993    15657105  Chukwualuka          726     Spain    Male  36.0
# 9995       9996    15606229     Obijiaku          771    France    Male  39.0
# 9996       9997    15569892    Johnstone          516    France    Male  35.0
# 9997       9998    15584532          Liu          709    France  Female  36.0
# 9998       9999    15682355    Sabbatini          772   Germany    Male  42.0
#
# ...

# %%
# Multiple conditions example
df.loc[(df['Age'] > 30) & (df['Age'] < 50)]
# Out:
#       RowNumber  CustomerId      Surname  CreditScore Geography  Gender   Age  \
# 1             2    15647311         Hill          608     Spain  Female  41.0
# 2             3    15619304         Onio          502    France  Female  42.0
# 3             4    15701354         Boni          699    France  Female  39.0
# 4             5    15737888     Mitchell          850     Spain  Female  43.0
# 5             6    15574012          Chu          645     Spain    Male  44.0
# ...         ...         ...          ...          ...       ...     ...   ...
# 9992       9993    15657105  Chukwualuka          726     Spain    Male  36.0
# 9995       9996    15606229     Obijiaku          771    France    Male  39.0
# 9996       9997    15569892    Johnstone          516    France    Male  35.0
# 9997       9998    15584532          Liu          709    France  Female  36.0
# 9998       9999    15682355    Sabbatini          772   Germany    Male  42.0
#
# ...

# %%
# With specific columns
df.loc[df['Age'] > 30, ['Surname', 'Age', 'Balance']]
# Out:
#           Surname   Age    Balance
# 1            Hill  41.0   83807.86
# 2            Onio  42.0  159660.80
# 3            Boni  39.0       0.00
# 4        Mitchell  43.0  125510.82
# 5             Chu  44.0  113755.78
# ...           ...   ...        ...
# 9992  Chukwualuka  36.0       0.00
# 9995     Obijiaku  39.0       0.00
# 9996    Johnstone  35.0   57369.61
# 9997          Liu  36.0       0.00
# 9998    Sabbatini  42.0   75075.31
#
# [8031 rows x 3 columns]

# %%
# Transpose column
df.T
# Out:
#                       0          1          2         3          4     \
# RowNumber                1          2          3         4          5
# CustomerId        15634602   15647311   15619304  15701354   15737888
# Surname           Hargrave       Hill       Onio      Boni   Mitchell
# CreditScore            619        608        502       699        850
# Geography           France      Spain     France    France      Spain
# Gender              Female     Female     Female    Female     Female
# Age                    NaN       41.0       42.0      39.0       43.0
# Tenure                   2          1          8         1          2
# Balance                0.0   83807.86   159660.8       0.0  125510.82
# NumOfProducts            1          1          3         2          1
# HasCrCard                1          0          1         0          1
# IsActiveMember           1          1          0         0          1
# ...

# %%
# sort your dataframe base on age
df.sort_values("Age")
# Out:
#       RowNumber  CustomerId          Surname  CreditScore Geography  Gender  \
# 9932       9933    15813451  Fleetwood-Smith          677     Spain    Male
# 3330       3331    15657439             Chao          738    France    Male
# 8522       8523    15619892             Page          644     Spain    Male
# 9520       9521    15673180      Onyekaozulu          727   Germany  Female
# 4556       4557    15796231          Nwankwo          681    France  Female
# ...         ...         ...              ...          ...       ...     ...
# 3033       3034    15578006              Yao          787    France  Female
# 2458       2459    15813303          Rearick          513     Spain    Male
# 6759       6760    15660878            T'ien          705    France    Male
# 6443       6444    15764927           Rogova          753    France    Male
# 0             1    15634602         Hargrave          619    France  Female
#
# ...

# %%
# create new column in a dataframe and assigned value 
df["New Balance me"]= df["Balance"] *2
df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender   Age  \
# 0             1    15634602   Hargrave          619    France  Female   NaN
# 1             2    15647311       Hill          608     Spain  Female  41.0
# 2             3    15619304       Onio          502    France  Female  42.0
# 3             4    15701354       Boni          699    France  Female  39.0
# 4             5    15737888   Mitchell          850     Spain  Female  43.0
# ...         ...         ...        ...          ...       ...     ...   ...
# 9995       9996    15606229   Obijiaku          771    France    Male  39.0
# 9996       9997    15569892  Johnstone          516    France    Male  35.0
# 9997       9998    15584532        Liu          709    France  Female  36.0
# 9998       9999    15682355  Sabbatini          772   Germany    Male  42.0
# 9999      10000    15628319     Walker          792    France  Female  28.0
#
# ...

# %%
# assigned new column with values
df["Random column"] = "Good day"
df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender   Age  \
# 0             1    15634602   Hargrave          619    France  Female   NaN
# 1             2    15647311       Hill          608     Spain  Female  41.0
# 2             3    15619304       Onio          502    France  Female  42.0
# 3             4    15701354       Boni          699    France  Female  39.0
# 4             5    15737888   Mitchell          850     Spain  Female  43.0
# ...         ...         ...        ...          ...       ...     ...   ...
# 9995       9996    15606229   Obijiaku          771    France    Male  39.0
# 9996       9997    15569892  Johnstone          516    France    Male  35.0
# 9997       9998    15584532        Liu          709    France  Female  36.0
# 9998       9999    15682355  Sabbatini          772   Germany    Male  42.0
# 9999      10000    15628319     Walker          792    France  Female  28.0
#
# ...

# %%
# creating new df but only if the condition is met
new_df_age_gretarer_50 = df[df["Age"]> 50]

# %%
new_df_age_gretarer_50.head()
# Out:
#     RowNumber  CustomerId  Surname  CreditScore Geography  Gender   Age  \
# 16         17    15737452    Romeo          653   Germany    Male  58.0
# 41         42    15738148   Clarke          465    France  Female  51.0
# 42         43    15687946  Osborne          556    France  Female  61.0
# 44         45    15684171  Bianchi          660     Spain  Female  61.0
# 58         59    15623944    T'ien          511     Spain  Female  66.0
#
#     Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 16       1  132602.88              1          1               0
# 41       8  122522.32              1          0               0
# 42       2  117419.35              1          1               1
# 44       5  155931.11              1          1               1
# 58       4       0.00              1          1               0
#
#     EstimatedSalary  Exited  New Balance me Random column
# 16          5097.67       1       265205.76      Good day
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              9999 non-null   float64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
#  14  New Balance me   10000 non-null  float64
#  15  Random column    10000 non-null  object
# dtypes: float64(4), int64(8), object(4)
# ...

# %%
df["Age"].isnull().sum()
# Out:
# np.int64(1)

# %%
mean_age = df["Age"].mean()
mean_age
# Out:
# np.float64(38.92149214921492)

# %%
# fill the null value with the mean age 
df["Age"].fillna(df["Age"].mean(), inplace = True)
df

#or 
#df["Age"].fillna(mean_age, inplace=True)
#df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  \
# 0             1    15634602   Hargrave          619    France  Female
# 1             2    15647311       Hill          608     Spain  Female
# 2             3    15619304       Onio          502    France  Female
# 3             4    15701354       Boni          699    France  Female
# 4             5    15737888   Mitchell          850     Spain  Female
# ...         ...         ...        ...          ...       ...     ...
# 9995       9996    15606229   Obijiaku          771    France    Male
# 9996       9997    15569892  Johnstone          516    France    Male
# 9997       9998    15584532        Liu          709    France  Female
# 9998       9999    15682355  Sabbatini          772   Germany    Male
# 9999      10000    15628319     Walker          792    France  Female
#
#             Age  Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
df["Age"].isnull().sum()
# Out:
# np.int64(0)

# %%
# drop all the null values in the age column
df["Age"].dropna(inplace=True)
df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  \
# 0             1    15634602   Hargrave          619    France  Female
# 1             2    15647311       Hill          608     Spain  Female
# 2             3    15619304       Onio          502    France  Female
# 3             4    15701354       Boni          699    France  Female
# 4             5    15737888   Mitchell          850     Spain  Female
# ...         ...         ...        ...          ...       ...     ...
# 9995       9996    15606229   Obijiaku          771    France    Male
# 9996       9997    15569892  Johnstone          516    France    Male
# 9997       9998    15584532        Liu          709    France  Female
# 9998       9999    15682355  Sabbatini          772   Germany    Male
# 9999      10000    15628319     Walker          792    France  Female
#
#             Age  Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  float64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
#  14  New Balance me   10000 non-null  float64
#  15  Random column    10000 non-null  object
# dtypes: float64(4), int64(8), object(4)
# ...

# %%
# delete one of the column
df.pop("RowNumber")
# Out:
# 0           1
# 1           2
# 2           3
# 3           4
# 4           5
#         ...
# 9995     9996
# 9996     9997
# 9997     9998
# 9998     9999
# 9999    10000
# Name: RowNumber, Length: 10000, dtype: int64

# %%
df.head()
# Out:
#    CustomerId   Surname  CreditScore Geography  Gender        Age  Tenure  \
# 0    15634602  Hargrave          619    France  Female  38.921492       2
# 1    15647311      Hill          608     Spain  Female  38.921492       1
# 2    15619304      Onio          502    France  Female  38.921492       8
# 3    15701354      Boni          699    France  Female  38.921492       1
# 4    15737888  Mitchell          850     Spain  Female  38.921492       2
#
#      Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# 0       0.00              1          1               1        101348.88
# 1   83807.86              1          0               1        112542.58
# 2  159660.80              3          1               0        113931.57
# 3       0.00              2          0               0         93826.63
# 4  125510.82              1          1               1         79084.10
#
#    Exited  New Balance me Random column
# 0       1            0.00      Good day
# ...

# %%
# check if column in dataframe
print(df.columns.tolist())
# Out:
# ['Surname', 'CreditScore', 'Geography', 'Gender', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard', 'IsActiveMember', 'EstimatedSalary', 'Exited', 'New Balance me', 'Random column']

# %%
df.head()
# Out:
#     Surname  CreditScore Geography  Gender        Age  Tenure    Balance  \
# 0  Hargrave          619    France  Female  38.921492       2       0.00
# 1      Hill          608     Spain  Female  38.921492       1   83807.86
# 2      Onio          502    France  Female  38.921492       8  159660.80
# 3      Boni          699    France  Female  38.921492       1       0.00
# 4  Mitchell          850     Spain  Female  38.921492       2  125510.82
#
#    NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  Exited  \
# 0              1          1               1        101348.88       1
# 1              1          0               1        112542.58       0
# 2              3          1               0        113931.57       1
# 3              2          0               0         93826.63       0
# 4              1          1               1         79084.10       0
#
#    New Balance me Random column
# 0            0.00      Good day
# 1       167615.72      Good day
# ...

# %%
if "Gender" in df.columns:
    df= df.drop("Gender", axis=1)

# %%
df.head()
# Out:
#     Surname  CreditScore Geography        Age  Tenure    Balance  \
# 0  Hargrave          619    France  38.921492       2       0.00
# 1      Hill          608     Spain  38.921492       1   83807.86
# 2      Onio          502    France  38.921492       8  159660.80
# 3      Boni          699    France  38.921492       1       0.00
# 4  Mitchell          850     Spain  38.921492       2  125510.82
#
#    NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  Exited  \
# 0              1          1               1        101348.88       1
# 1              1          0               1        112542.58       0
# 2              3          1               0        113931.57       1
# 3              2          0               0         93826.63       0
# 4              1          1               1         79084.10       0
#
#    New Balance me Random column
# 0            0.00      Good day
# 1       167615.72      Good day
# 2       319321.60      Good day
# ...

# %%
df["Balance"]
# Out:
# 0            0.00
# 1        83807.86
# 2       159660.80
# 3            0.00
# 4       125510.82
#           ...
# 9995         0.00
# 9996     57369.61
# 9997         0.00
# 9998     75075.31
# 9999    130142.79
# Name: Balance, Length: 10000, dtype: float64

# %%
df["Balance"].apply(np.sqrt)
# Out:
# 0         0.000000
# 1       289.495872
# 2       399.575775
# 3         0.000000
# 4       354.275063
#            ...
# 9995      0.000000
# 9996    239.519540
# 9997      0.000000
# 9998    273.998741
# 9999    360.753087
# Name: Balance, Length: 10000, dtype: float64

# %%
df["sqrt column"] = df["Balance"].apply(np.sqrt)

# %%
df.head()
# Out:
#     Surname  CreditScore Geography        Age  Tenure    Balance  \
# 0  Hargrave          619    France  38.921492       2       0.00
# 1      Hill          608     Spain  38.921492       1   83807.86
# 2      Onio          502    France  38.921492       8  159660.80
# 3      Boni          699    France  38.921492       1       0.00
# 4  Mitchell          850     Spain  38.921492       2  125510.82
#
#    NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  Exited  \
# 0              1          1               1        101348.88       1
# 1              1          0               1        112542.58       0
# 2              3          1               0        113931.57       1
# 3              2          0               0         93826.63       0
# 4              1          1               1         79084.10       0
#
#    New Balance me Random column  sqrt column
# 0            0.00      Good day     0.000000
# 1       167615.72      Good day   289.495872
# ...

# %%
df.isnull().sum()
# Out:
# Surname            0
# CreditScore        0
# Geography          0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# New Balance me     0
# Random column      0
# sqrt column        0
# dtype: int64

# %%
dff = pd.DataFrame({
    'A': [1, None, 3],
    'B': [4, 5, None],
    'C': [7, 8, 9]
})

# %%
dff
# Out:
#      A    B  C
# 0  1.0  4.0  7
# 1  NaN  5.0  8
# 2  3.0  NaN  9

# %%
dff.isnull().sum()
# Out:
# A    1
# B    1
# C    0
# dtype: int64

# %%
df.dropna(subset=["A","B"],inplace=True)

# %%
dff
# Out:
#      A    B  C
# 0  1.0  4.0  7
# 1  NaN  5.0  8
# 2  3.0  NaN  9

# %%
dff.dropna()
dff
# Out:
#      A    B  C
# 0  1.0  4.0  7
# 1  NaN  5.0  8
# 2  3.0  NaN  9

# %%
dff.fillna(df["A"].mean(), inplace=True)

# %%
dff
# Out:
#      A    B  C
# 0  1.0  4.0  7
# 1  1.0  5.0  8
# 2  3.0  1.0  9

# %%
dff
# Out:
#      A    B  C
# 0  1.0  4.0  7
# 1  1.0  5.0  8
# 2  3.0  1.0  9
